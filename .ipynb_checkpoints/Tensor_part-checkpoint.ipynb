# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import tensorflow_probability as tfp
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import scipy.io #to read MATLAB data
import scipy.optimize as sopt
import time
import matplotlib.gridspec as gridspec
# Out:
# 2023-04-30 18:10:09.150149: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-30 18:10:09.152344: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-30 18:10:09.181883: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-30 18:10:09.182394: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-30 18:10:09.744693: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
tf.compat.v1.Session().run()

# %%
np.random.seed(42)
tf.random.set_seed(42)
tf.compat.v1.disable_eager_execution()

# %%
tfp.optimizer.lbfgs_minimize()

# %%
class PINN:
    def __init__(self, X, u, layers, lb, ub):
        self.lb = lb
        self.ub = ub
        
        print(X)
        self.x = X[:, 0:1]
        self.t = X[:, 1:2]
        self.u = u
        
        print(self.u.shape)
        
        self.layers = layers
        
         # Initialize NNs
        self.weights, self.biases = self.initialize_NN(self.layers)
        
        # tf placeholders and graph
        # sess - session
        self.sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(allow_soft_placement=True,
                                                                         log_device_placement=True))

        # Initialize parameters
        self.lambda_1 = tf.Variable([0, 0], dtype=tf.float32)
        self.lambda_2 = tf.Variable([-6, 0], dtype=tf.float32)
        
        # print(self.x.shape)
        # print(self.x)
        # print(self.t.shape)
        self.x_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.x.shape[1]])
        self.t_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.t.shape[1]])
        self.u_tf = tf.compat.v1.placeholder(tf.float32, shape=[None, self.u.shape[1]])
        
        self.u_pred = self.net_u(self.x_tf, self.t_tf)
        self.f_pred = self.net_f(self.x_tf, self.t_tf)
        
        print(self.u_tf)
        print(tf.shape(self.u_tf))
        # MSE = MSE(u) + MSE(f)
        self.loss = tf.math.reduce_mean(tf.square(self.u_tf - self.u_pred)) + tf.math.reduce_mean(tf.square(self.f_pred))
        
        self.optimizer = tfp.optimizer.lbfgs_minimize(value_and_gradients_function=self.loss,
                                                     initial_position=self.weights,
                                                     previous_optimizer_results=None,
                                                     num_correction_pairs=50, # maxcor
                                                     tolerance=1e-08,
                                                     x_tolerance=0,
                                                     f_relative_tolerance=1.0 * np.finfo(float).eps, # ftol
                                                     initial_inverse_hessian_estimate=None,
                                                     max_iterations=50000, # maxiter
                                                     parallel_iterations=1,
                                                     stopping_condition=None,
                                                     max_line_search_iterations=50, # maxls
                                                     f_absolute_tolerance=0,
                                                     name=None)
#         tfp.optimizer.lbfgs_minimize(value_and_gradients_function=self.loss,
#                                                       initial_position,
#                                                       previous_optimizer_results=None,
#                                                       num_correction_pairs=50, # maxcor
#                                                       tolerance=1e-08,
#                                                       x_tolerance=0,
#                                                       f_relative_tolerance=1.0 * np.finfo(float).eps, # ftol
#                                                       initial_inverse_hessian_estimate=None,
#                                                       max_iterations=50000, # maxiter
#                                                       parallel_iterations=1,
#                                                       stopping_condition=None,
#                                                       max_line_search_iterations=50, # maxls
#                                                       f_absolute_tolerance=0,
#                                                       name=None)

        
#         tf.compat.v1.estimator.optimizer.ScipyOptimizerInterface(self.loss, 
#                                                                 method = 'L-BFGS-B', 
#                                                                 options = {'maxiter': 50000,
#                                                                            'maxfun': 50000,
#                                                                            'maxcor': 50,
#                                                                            'maxls': 50,
#                                                                            'ftol' : 1.0 * np.finfo(float).eps})
        
        self.optimizer_Adam = tf.compat.v1.train.AdamOptimizer()
        self.train_op_Adam = self.optimizer_Adam.minimize(self.loss)
        
        init = tf.compat.v1.global_variables_initializer()
        self.sess.run(init)
        
        
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0,num_layers-1):
            W = self.xavier_init(size=[layers[l], layers[l+1]])
            b = tf.Variable(tf.zeros([1,layers[l+1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)        
        return weights, biases
    
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_std_dev = tf.sqrt(2/(in_dim + out_dim))
        return tf.Variable(tf.random.truncated_normal([in_dim, out_dim], stddev=xavier_std_dev), dtype=tf.float32)

    def neural_net(self, X, weights, biases):
        num_layers = len(self.layers)
        
        H = 2.0*(X - self.lb)/(self.ub - self.lb) - 1.0
        for l in range(0,num_layers-1):
            W = weights[l]
            b = biases[l]
            H = tf.math.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y
            
    def net_u(self, x, t):  
        u = self.neural_net(tf.concat([x,t],1), self.weights, self.biases)
        return u

    def net_f(self, x, t):
        lambda_1 = self.lambda_1        
        lambda_2 = tf.exp(self.lambda_2)
        u = self.net_u(x,t)
        u_t = tf.gradients(u, t)[0]
        u_x = tf.gradients(u, x)[0]
        u_xx = tf.gradients(u_x, x)[0]
        f = u_t + lambda_1*u*u_x - lambda_2*u_xx

        return f

    def callback(self, loss, lambda_1, lambda_2):
        print(f"Loss: {loss:e}, l1: {lambda_1:.5f}, l2: {np.exp(lambda_2):.5f}")


    def train(self, nIter):
        tf_dict = {self.x_tf: self.x, self.t_tf: self.t, self.u_tf: self.u}

        start_time = time.time()
        for it in range(nIter):
            self.sess.run(self.train_op_Adam, tf_dict)

            # Print
            if it % 10 == 0:
                elapsed = time.time() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                lambda_1_value, lambda_2_value = self.sess.run([self.lambda_1, self.lambda_2])
                lambda_2_value = tf.exp(lambda_2_value)
                print(f"Iteration: {it}, Loss: {loss_value:.3e}, Lambda_1: {lambda_1_value:.3f}, Lambda_2: {lambda_2_value:.6f}, Time: {elapsed:.2f}")
                start_time = time.time()

        self.optimizer.minimize(self.sess, feed_dict=tf_dict, fetches=[self.loss, self.lambda_1, self.lambda_2], loss_callback=self.callback)

    def predict(self, X_star):
        tf_dict = {self.x_tf: X_star[:, 0:1], self.t_tf: X_star[:, 1:2]}

        u_star, f_star = self.sess.run([self.u_pred, self.f_pred], feed_dict=tf_dict)

        return u_star, f_star

# %%
if __name__ == "__main__": 
     
    nu = 0.01/np.pi

    N_u = 2000
    layers = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]
    
    data = scipy.io.loadmat('burgers_shock.mat')
    
    t = data['t'].flatten()[:,None] # time discretization points
    x = data['x'].flatten()[:,None] # spatial discretization points (1-D)
    Exact = np.real(data['usol']).T # exact solution
    
    X, T = np.meshgrid(x,t) # create a mesh from data coordinates x,t
    
    X_star = np.hstack((X.flatten()[:,None], T.flatten()[:,None])) # includes spatial and time coordinates
    u_star = Exact.flatten()[:,None]              

    # Doman bounds
    lb = X_star.min(0)
    ub = X_star.max(0)
    
    
    ######################################################################
    ######################## Noiseles Data ###############################
    ######################################################################
    noise = 0.0

    # Randomly sample data points for training
    idx = np.random.choice(X_star.shape[0], N_u, replace=False)
    X_u_train = X_star[idx, :]
    u_train = u_star[idx, :]

    # print(X_u_train)
    # print(X_u_train.shape)
    # Create the model and train
    model = PINN(X_u_train, u_train, layers, lb, ub)
    model.train(nIter=0)

    # Predict and evaluate
    u_pred, f_pred = model.predict(X_star)

    error_u = np.linalg.norm(u_star - u_pred, ord=2) / np.linalg.norm(u_star, ord=2)

    U_pred = griddata(X_star, u_pred.flatten(), (X, T), method='cubic')

    lambda_1_value, lambda_2_value = model.sess.run([model.lambda_1, model.lambda_2])
    lambda_2_value = ts.exp(lambda_2_value)

    error_lambda_1 = tf.math.abs(lambda_1_value - 1.0) * 100
    error_lambda_2 = tf.math.abs(lambda_2_value - nu) / nu * 100

    print(f"Error u: {error_u:e}")
    print(f"Error l1: {error_lambda_1:.5f}%")
    print(f"Error l2: {error_lambda_2:.5f}%")
    
    
    ######################################################################
    ########################### Noisy Data ###############################
    ######################################################################
    noise = 0.01        
    u_train = u_train + noise*np.std(u_train)*np.random.randn(u_train.shape[0], u_train.shape[1])

    model = PINN(X_u_train, u_train, layers, lb, ub)
    model.train(10000)

    u_pred, f_pred = model.predict(X_star)

    lambda_1_value_noisy = model.sess.run(model.lambda_1)
    lambda_2_value_noisy = model.sess.run(model.lambda_2)
    lambda_2_value_noisy = tf.exp(lambda_2_value_noisy)

    error_lambda_1_noisy = tf.math.abs(lambda_1_value_noisy - 1.0)*100
    error_lambda_2_noisy = tf.math.abs(lambda_2_value_noisy - nu)/nu * 100

    print(f'Error lambda_1: {error_lambda_1_noisy:.2f}%')
    print(f'Error lambda_2: {error_lambda_2_noisy:.2f}%')
    
    
    
    ######################################################################
    ############################# Plotting ###############################
    ######################################################################  
    
    fig, ax = newfig(1.0, 1.4)
    ax.axis('off')

    # Define constants
    data_label = f'Data ({u_train.shape[0]} points)'

    # Row 0: u(t,x)
    gs0 = gridspec.GridSpec(1, 2)
    gs0.update(top=1-0.06, bottom=1-1.0/3.0+0.06, left=0.15, right=0.85, wspace=0)

    h = ax.imshow(U_pred.T, interpolation='nearest', cmap='rainbow', 
                  extent=[t.min(), t.max(), x.min(), x.max()], 
                  origin='lower', aspect='auto')
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    fig.colorbar(h, cax=cax)

    ax.plot(X_u_train[:,1], X_u_train[:,0], 'kx', label=data_label, markersize=2, clip_on=False)

    line = np.linspace(x.min(), x.max(), 2)[:,None]
    ax.plot(t[25]*np.ones((2,1)), line, 'w-', linewidth=1)
    ax.plot(t[50]*np.ones((2,1)), line, 'w-', linewidth=1)
    ax.plot(t[75]*np.ones((2,1)), line, 'w-', linewidth=1)

    ax.set_xlabel('$t$')
    ax.set_ylabel('$x$')
    ax.legend(loc='upper center', bbox_to_anchor=(1.0, -0.125), ncol=5, frameon=False)
    ax.set_title('$u(t,x)$', fontsize=10)

    
    ####### Row 1: u(t,x) slices ##################  
    gs1 = gridspec.GridSpec(1, 3)
    gs1.update(top=1-1.0/3.0-0.1, bottom=1.0-2.0/3.0, left=0.1, right=0.9, wspace=0.5)
    
    ax = plt.subplot(gs1[0, 0])
    ax.plot(x,Exact[25,:], 'b-', linewidth = 2, label = 'Exact')       
    ax.plot(x,U_pred[25,:], 'r--', linewidth = 2, label = 'Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')    
    ax.set_title('$t = 0.25$', fontsize = 10)
    ax.axis('square')
    ax.set_xlim([-1.1,1.1])
    ax.set_ylim([-1.1,1.1])
    
    ax = plt.subplot(gs1[0, 1])
    ax.plot(x,Exact[50,:], 'b-', linewidth = 2, label = 'Exact')       
    ax.plot(x,U_pred[50,:], 'r--', linewidth = 2, label = 'Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')
    ax.axis('square')
    ax.set_xlim([-1.1,1.1])
    ax.set_ylim([-1.1,1.1])
    ax.set_title('$t = 0.50$', fontsize = 10)
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.35), ncol=5, frameon=False)
    
    ax = plt.subplot(gs1[0, 2])
    ax.plot(x,Exact[75,:], 'b-', linewidth = 2, label = 'Exact')       
    ax.plot(x,U_pred[75,:], 'r--', linewidth = 2, label = 'Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')
    ax.axis('square')
    ax.set_xlim([-1.1,1.1])
    ax.set_ylim([-1.1,1.1])    
    ax.set_title('$t = 0.75$', fontsize = 10)
    
    
    ####### Row 3: Identified PDE ##################    
    gs2 = gridspec.GridSpec(1, 3)
    gs2.update(top=1.0-2.0/3.0, bottom=0, left=0.0, right=1.0, wspace=0.0)
    
    ax = plt.subplot(gs2[:, :])
    ax.axis('off')
    
    s1 = "$\\begin{{tabular}}{{ |c|c| }} \\hline Correct PDE & $u_t + u u_x - 0.0031831 u_{{xx}} = 0$ \\\\ \\hline Identified PDE (clean data) & "
    s2 = f"$u_t + {lambda_1_value:.5f} u u_x - {lambda_2_value:.7f} u_{{xx}} = 0$ \\\\ \\hline Identified PDE (1\\% noise) & "
    s3 = f"$u_t + {lambda_1_value_noisy:.5f} u u_x - {lambda_2_value_noisy:.7f} u_{{xx}} = 0$ \\\\ \\hline \\end{{tabular}}$"
    s = s1 + s2 + s3
    ax.text(0.1, 0.1, s)
# Out:
# [[-0.16078431  0.39      ]
#  [ 0.01960784  0.98      ]
#  [ 0.03529412  0.81      ]
#  ...
#  [-0.45882353  0.86      ]
#  [ 0.6627451   0.17      ]
#  [ 0.14509804  0.        ]]
# (2000, 1)
# Device mapping: no known devices.
# 2023-04-30 16:09:15.619588: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-30 16:09:15.623775: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-04-30 16:09:15.623804: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-04-30 16:09:15.623835: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (mksash-xps9310): /proc/driver/nvidia/version does not exist
# Tensor("Placeholder_2:0", shape=(None, 1), dtype=float32)
# Tensor("Shape:0", shape=(2,), dtype=int32)
# 2023-04-30 16:09:17.065427: I tensorflow/core/common_runtime/placer.cc:114] Sqrt: (Sqrt): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065469: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065475: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065480: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065486: I tensorflow/core/common_runtime/placer.cc:114] Variable/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065492: I tensorflow/core/common_runtime/placer.cc:114] Variable/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065496: I tensorflow/core/common_runtime/placer.cc:114] Variable/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065501: I tensorflow/core/common_runtime/placer.cc:114] Variable_1/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065505: I tensorflow/core/common_runtime/placer.cc:114] Variable_1/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065510: I tensorflow/core/common_runtime/placer.cc:114] Variable_1/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065515: I tensorflow/core/common_runtime/placer.cc:114] Sqrt_1: (Sqrt): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065520: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_1/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065525: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_1/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065529: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_1: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065537: I tensorflow/core/common_runtime/placer.cc:114] Variable_2/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065544: I tensorflow/core/common_runtime/placer.cc:114] Variable_2/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065548: I tensorflow/core/common_runtime/placer.cc:114] Variable_2/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065553: I tensorflow/core/common_runtime/placer.cc:114] Variable_3/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065558: I tensorflow/core/common_runtime/placer.cc:114] Variable_3/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065562: I tensorflow/core/common_runtime/placer.cc:114] Variable_3/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065567: I tensorflow/core/common_runtime/placer.cc:114] Sqrt_2: (Sqrt): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065572: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_2/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065578: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_2/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065582: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_2: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065587: I tensorflow/core/common_runtime/placer.cc:114] Variable_4/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065592: I tensorflow/core/common_runtime/placer.cc:114] Variable_4/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065598: I tensorflow/core/common_runtime/placer.cc:114] Variable_4/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065603: I tensorflow/core/common_runtime/placer.cc:114] Variable_5/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065607: I tensorflow/core/common_runtime/placer.cc:114] Variable_5/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065611: I tensorflow/core/common_runtime/placer.cc:114] Variable_5/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065616: I tensorflow/core/common_runtime/placer.cc:114] Sqrt_3: (Sqrt): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065621: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_3/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065626: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_3/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065631: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_3: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065636: I tensorflow/core/common_runtime/placer.cc:114] Variable_6/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065641: I tensorflow/core/common_runtime/placer.cc:114] Variable_6/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065645: I tensorflow/core/common_runtime/placer.cc:114] Variable_6/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065650: I tensorflow/core/common_runtime/placer.cc:114] Variable_7/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065655: I tensorflow/core/common_runtime/placer.cc:114] Variable_7/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065659: I tensorflow/core/common_runtime/placer.cc:114] Variable_7/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065663: I tensorflow/core/common_runtime/placer.cc:114] Sqrt_4: (Sqrt): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065668: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_4/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065674: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_4/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065682: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_4: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065689: I tensorflow/core/common_runtime/placer.cc:114] Variable_8/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065696: I tensorflow/core/common_runtime/placer.cc:114] Variable_8/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065707: I tensorflow/core/common_runtime/placer.cc:114] Variable_8/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065713: I tensorflow/core/common_runtime/placer.cc:114] Variable_9/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065721: I tensorflow/core/common_runtime/placer.cc:114] Variable_9/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065728: I tensorflow/core/common_runtime/placer.cc:114] Variable_9/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065737: I tensorflow/core/common_runtime/placer.cc:114] Sqrt_5: (Sqrt): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065746: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_5/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065754: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_5/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065759: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_5: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065766: I tensorflow/core/common_runtime/placer.cc:114] Variable_10/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065774: I tensorflow/core/common_runtime/placer.cc:114] Variable_10/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065780: I tensorflow/core/common_runtime/placer.cc:114] Variable_10/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065785: I tensorflow/core/common_runtime/placer.cc:114] Variable_11/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065790: I tensorflow/core/common_runtime/placer.cc:114] Variable_11/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065794: I tensorflow/core/common_runtime/placer.cc:114] Variable_11/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065799: I tensorflow/core/common_runtime/placer.cc:114] Sqrt_6: (Sqrt): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065804: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_6/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065809: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_6/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065813: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_6: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065818: I tensorflow/core/common_runtime/placer.cc:114] Variable_12/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065823: I tensorflow/core/common_runtime/placer.cc:114] Variable_12/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065827: I tensorflow/core/common_runtime/placer.cc:114] Variable_12/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065832: I tensorflow/core/common_runtime/placer.cc:114] Variable_13/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065836: I tensorflow/core/common_runtime/placer.cc:114] Variable_13/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065841: I tensorflow/core/common_runtime/placer.cc:114] Variable_13/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065846: I tensorflow/core/common_runtime/placer.cc:114] Sqrt_7: (Sqrt): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065851: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_7/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065856: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_7/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065861: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_7: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065866: I tensorflow/core/common_runtime/placer.cc:114] Variable_14/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065871: I tensorflow/core/common_runtime/placer.cc:114] Variable_14/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065875: I tensorflow/core/common_runtime/placer.cc:114] Variable_14/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065880: I tensorflow/core/common_runtime/placer.cc:114] Variable_15/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065884: I tensorflow/core/common_runtime/placer.cc:114] Variable_15/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065889: I tensorflow/core/common_runtime/placer.cc:114] Variable_15/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065894: I tensorflow/core/common_runtime/placer.cc:114] Sqrt_8: (Sqrt): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065899: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_8/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065904: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_8/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065909: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_8: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065914: I tensorflow/core/common_runtime/placer.cc:114] Variable_16/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065918: I tensorflow/core/common_runtime/placer.cc:114] Variable_16/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065923: I tensorflow/core/common_runtime/placer.cc:114] Variable_16/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065928: I tensorflow/core/common_runtime/placer.cc:114] Variable_17/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065932: I tensorflow/core/common_runtime/placer.cc:114] Variable_17/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065936: I tensorflow/core/common_runtime/placer.cc:114] Variable_17/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065941: I tensorflow/core/common_runtime/placer.cc:114] Variable_18/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065947: I tensorflow/core/common_runtime/placer.cc:114] Variable_18/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065951: I tensorflow/core/common_runtime/placer.cc:114] Variable_18/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065956: I tensorflow/core/common_runtime/placer.cc:114] Variable_19/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065960: I tensorflow/core/common_runtime/placer.cc:114] Variable_19/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065964: I tensorflow/core/common_runtime/placer.cc:114] Variable_19/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065970: I tensorflow/core/common_runtime/placer.cc:114] concat: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065975: I tensorflow/core/common_runtime/placer.cc:114] sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065980: I tensorflow/core/common_runtime/placer.cc:114] mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065986: I tensorflow/core/common_runtime/placer.cc:114] truediv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065991: I tensorflow/core/common_runtime/placer.cc:114] sub_1: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.065995: I tensorflow/core/common_runtime/placer.cc:114] MatMul/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066000: I tensorflow/core/common_runtime/placer.cc:114] MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066004: I tensorflow/core/common_runtime/placer.cc:114] Add/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066009: I tensorflow/core/common_runtime/placer.cc:114] Add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066014: I tensorflow/core/common_runtime/placer.cc:114] Tanh: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066018: I tensorflow/core/common_runtime/placer.cc:114] MatMul_1/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066023: I tensorflow/core/common_runtime/placer.cc:114] MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066027: I tensorflow/core/common_runtime/placer.cc:114] Add_1/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066032: I tensorflow/core/common_runtime/placer.cc:114] Add_1: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066037: I tensorflow/core/common_runtime/placer.cc:114] Tanh_1: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066041: I tensorflow/core/common_runtime/placer.cc:114] MatMul_2/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066045: I tensorflow/core/common_runtime/placer.cc:114] MatMul_2: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066049: I tensorflow/core/common_runtime/placer.cc:114] Add_2/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066054: I tensorflow/core/common_runtime/placer.cc:114] Add_2: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066059: I tensorflow/core/common_runtime/placer.cc:114] Tanh_2: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066063: I tensorflow/core/common_runtime/placer.cc:114] MatMul_3/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066068: I tensorflow/core/common_runtime/placer.cc:114] MatMul_3: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066072: I tensorflow/core/common_runtime/placer.cc:114] Add_3/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066078: I tensorflow/core/common_runtime/placer.cc:114] Add_3: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066082: I tensorflow/core/common_runtime/placer.cc:114] Tanh_3: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066086: I tensorflow/core/common_runtime/placer.cc:114] MatMul_4/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066091: I tensorflow/core/common_runtime/placer.cc:114] MatMul_4: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066095: I tensorflow/core/common_runtime/placer.cc:114] Add_4/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066100: I tensorflow/core/common_runtime/placer.cc:114] Add_4: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066105: I tensorflow/core/common_runtime/placer.cc:114] Tanh_4: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066109: I tensorflow/core/common_runtime/placer.cc:114] MatMul_5/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066114: I tensorflow/core/common_runtime/placer.cc:114] MatMul_5: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066118: I tensorflow/core/common_runtime/placer.cc:114] Add_5/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066123: I tensorflow/core/common_runtime/placer.cc:114] Add_5: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066127: I tensorflow/core/common_runtime/placer.cc:114] Tanh_5: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066131: I tensorflow/core/common_runtime/placer.cc:114] MatMul_6/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066136: I tensorflow/core/common_runtime/placer.cc:114] MatMul_6: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066140: I tensorflow/core/common_runtime/placer.cc:114] Add_6/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066144: I tensorflow/core/common_runtime/placer.cc:114] Add_6: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066149: I tensorflow/core/common_runtime/placer.cc:114] Tanh_6: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066153: I tensorflow/core/common_runtime/placer.cc:114] MatMul_7/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066160: I tensorflow/core/common_runtime/placer.cc:114] MatMul_7: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066164: I tensorflow/core/common_runtime/placer.cc:114] Add_7/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066169: I tensorflow/core/common_runtime/placer.cc:114] Add_7: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066174: I tensorflow/core/common_runtime/placer.cc:114] Tanh_7: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066179: I tensorflow/core/common_runtime/placer.cc:114] MatMul_8/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066184: I tensorflow/core/common_runtime/placer.cc:114] MatMul_8: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066189: I tensorflow/core/common_runtime/placer.cc:114] Add_8/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066194: I tensorflow/core/common_runtime/placer.cc:114] Add_8: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066199: I tensorflow/core/common_runtime/placer.cc:114] Exp/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066204: I tensorflow/core/common_runtime/placer.cc:114] Exp: (Exp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066211: I tensorflow/core/common_runtime/placer.cc:114] concat_1: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066217: I tensorflow/core/common_runtime/placer.cc:114] sub_2: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066222: I tensorflow/core/common_runtime/placer.cc:114] mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066228: I tensorflow/core/common_runtime/placer.cc:114] truediv_1: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066233: I tensorflow/core/common_runtime/placer.cc:114] sub_3: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066238: I tensorflow/core/common_runtime/placer.cc:114] MatMul_9/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066244: I tensorflow/core/common_runtime/placer.cc:114] MatMul_9: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066249: I tensorflow/core/common_runtime/placer.cc:114] Add_9/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066255: I tensorflow/core/common_runtime/placer.cc:114] Add_9: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066260: I tensorflow/core/common_runtime/placer.cc:114] Tanh_8: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066265: I tensorflow/core/common_runtime/placer.cc:114] MatMul_10/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066270: I tensorflow/core/common_runtime/placer.cc:114] MatMul_10: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066275: I tensorflow/core/common_runtime/placer.cc:114] Add_10/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066280: I tensorflow/core/common_runtime/placer.cc:114] Add_10: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066286: I tensorflow/core/common_runtime/placer.cc:114] Tanh_9: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066290: I tensorflow/core/common_runtime/placer.cc:114] MatMul_11/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066296: I tensorflow/core/common_runtime/placer.cc:114] MatMul_11: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066300: I tensorflow/core/common_runtime/placer.cc:114] Add_11/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066307: I tensorflow/core/common_runtime/placer.cc:114] Add_11: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066312: I tensorflow/core/common_runtime/placer.cc:114] Tanh_10: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066317: I tensorflow/core/common_runtime/placer.cc:114] MatMul_12/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066322: I tensorflow/core/common_runtime/placer.cc:114] MatMul_12: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066327: I tensorflow/core/common_runtime/placer.cc:114] Add_12/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066332: I tensorflow/core/common_runtime/placer.cc:114] Add_12: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066338: I tensorflow/core/common_runtime/placer.cc:114] Tanh_11: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066342: I tensorflow/core/common_runtime/placer.cc:114] MatMul_13/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066348: I tensorflow/core/common_runtime/placer.cc:114] MatMul_13: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066352: I tensorflow/core/common_runtime/placer.cc:114] Add_13/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066358: I tensorflow/core/common_runtime/placer.cc:114] Add_13: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066363: I tensorflow/core/common_runtime/placer.cc:114] Tanh_12: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066368: I tensorflow/core/common_runtime/placer.cc:114] MatMul_14/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066373: I tensorflow/core/common_runtime/placer.cc:114] MatMul_14: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066378: I tensorflow/core/common_runtime/placer.cc:114] Add_14/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066383: I tensorflow/core/common_runtime/placer.cc:114] Add_14: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066389: I tensorflow/core/common_runtime/placer.cc:114] Tanh_13: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066394: I tensorflow/core/common_runtime/placer.cc:114] MatMul_15/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066400: I tensorflow/core/common_runtime/placer.cc:114] MatMul_15: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066404: I tensorflow/core/common_runtime/placer.cc:114] Add_15/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066410: I tensorflow/core/common_runtime/placer.cc:114] Add_15: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066415: I tensorflow/core/common_runtime/placer.cc:114] Tanh_14: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066420: I tensorflow/core/common_runtime/placer.cc:114] MatMul_16/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066425: I tensorflow/core/common_runtime/placer.cc:114] MatMul_16: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066430: I tensorflow/core/common_runtime/placer.cc:114] Add_16/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066435: I tensorflow/core/common_runtime/placer.cc:114] Add_16: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066441: I tensorflow/core/common_runtime/placer.cc:114] Tanh_15: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066446: I tensorflow/core/common_runtime/placer.cc:114] MatMul_17/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066451: I tensorflow/core/common_runtime/placer.cc:114] MatMul_17: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066459: I tensorflow/core/common_runtime/placer.cc:114] Add_17/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066470: I tensorflow/core/common_runtime/placer.cc:114] Add_17: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066477: I tensorflow/core/common_runtime/placer.cc:114] gradients/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066484: I tensorflow/core/common_runtime/placer.cc:114] gradients/grad_ys_0: (Fill): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066495: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_17_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066503: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_17_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066510: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_17_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066518: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_17_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066523: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_17_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066529: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_17_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066533: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_17_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066538: I tensorflow/core/common_runtime/placer.cc:114] gradients/MatMul_17_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066543: I tensorflow/core/common_runtime/placer.cc:114] gradients/MatMul_17_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066549: I tensorflow/core/common_runtime/placer.cc:114] gradients/Tanh_15_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066554: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_16_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066559: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_16_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066563: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_16_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066568: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_16_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066572: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_16_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066580: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_16_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066585: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_16_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066590: I tensorflow/core/common_runtime/placer.cc:114] gradients/MatMul_16_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066595: I tensorflow/core/common_runtime/placer.cc:114] gradients/MatMul_16_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066600: I tensorflow/core/common_runtime/placer.cc:114] gradients/Tanh_14_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066605: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_15_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066609: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_15_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066614: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_15_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066619: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_15_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066623: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_15_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066628: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_15_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066632: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_15_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066637: I tensorflow/core/common_runtime/placer.cc:114] gradients/MatMul_15_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066642: I tensorflow/core/common_runtime/placer.cc:114] gradients/MatMul_15_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066647: I tensorflow/core/common_runtime/placer.cc:114] gradients/Tanh_13_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066652: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_14_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066656: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_14_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066661: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_14_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066667: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_14_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066671: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_14_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066676: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_14_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066680: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_14_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066688: I tensorflow/core/common_runtime/placer.cc:114] gradients/MatMul_14_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066692: I tensorflow/core/common_runtime/placer.cc:114] gradients/MatMul_14_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066697: I tensorflow/core/common_runtime/placer.cc:114] gradients/Tanh_12_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066702: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_13_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066707: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_13_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066712: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_13_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066720: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_13_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066724: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_13_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066729: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_13_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066734: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_13_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066739: I tensorflow/core/common_runtime/placer.cc:114] gradients/MatMul_13_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066744: I tensorflow/core/common_runtime/placer.cc:114] gradients/MatMul_13_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066749: I tensorflow/core/common_runtime/placer.cc:114] gradients/Tanh_11_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066754: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_12_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066760: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_12_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066765: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_12_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066770: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_12_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066774: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_12_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066779: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_12_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066796: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_12_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066801: I tensorflow/core/common_runtime/placer.cc:114] gradients/MatMul_12_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066806: I tensorflow/core/common_runtime/placer.cc:114] gradients/MatMul_12_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066811: I tensorflow/core/common_runtime/placer.cc:114] gradients/Tanh_10_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066816: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_11_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066821: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_11_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066828: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_11_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066835: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_11_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066840: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_11_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066844: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_11_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066852: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_11_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066860: I tensorflow/core/common_runtime/placer.cc:114] gradients/MatMul_11_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066868: I tensorflow/core/common_runtime/placer.cc:114] gradients/MatMul_11_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066876: I tensorflow/core/common_runtime/placer.cc:114] gradients/Tanh_9_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066885: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_10_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066893: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_10_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066901: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_10_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066908: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_10_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066915: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_10_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066923: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_10_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066930: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_10_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066938: I tensorflow/core/common_runtime/placer.cc:114] gradients/MatMul_10_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066946: I tensorflow/core/common_runtime/placer.cc:114] gradients/MatMul_10_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066954: I tensorflow/core/common_runtime/placer.cc:114] gradients/Tanh_8_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066963: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_9_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066971: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_9_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066979: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_9_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066987: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_9_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.066994: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_9_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.067002: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_9_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.067010: I tensorflow/core/common_runtime/placer.cc:114] gradients/Add_9_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.067017: I tensorflow/core/common_runtime/placer.cc:114] gradients/MatMul_9_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.067024: I tensorflow/core/common_runtime/placer.cc:114] gradients/MatMul_9_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.067033: I tensorflow/core/common_runtime/placer.cc:114] gradients/sub_3_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.067041: I tensorflow/core/common_runtime/placer.cc:114] gradients/sub_3_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.067048: I tensorflow/core/common_runtime/placer.cc:114] gradients/sub_3_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.067055: I tensorflow/core/common_runtime/placer.cc:114] gradients/sub_3_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.067060: I tensorflow/core/common_runtime/placer.cc:114] gradients/sub_3_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.067068: I tensorflow/core/common_runtime/placer.cc:114] gradients/sub_3_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-04-30 16:09:17.067077: I tensorflow/core/common_runtime/placer.cc:114] gradients/sub_3_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# ...
# gradients_3/gradients_2/Add_12_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Add_13_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Add_13_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Add_13_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Add_13_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Tanh_11_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Tanh_12_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Add_14_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Add_14_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Add_14_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Add_14_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Add_13_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Add_13_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Add_13_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Add_13_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Tanh_13_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Tanh_12_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Add_15_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Add_15_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Add_15_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Add_15_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Tanh_14_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Add_14_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Add_14_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Add_14_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Add_14_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Tanh_13_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Add_16_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Add_16_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Add_16_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Add_16_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients/Tanh_15_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Add_15_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Add_15_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Add_15_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Add_15_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Tanh_14_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Add_16_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Add_16_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Add_16_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Add_16_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/Tanh_15_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/gradients_1/Tanh_14_grad/TanhGrad_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/gradients_1/Tanh_13_grad/TanhGrad_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/gradients_1/Tanh_12_grad/TanhGrad_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/gradients_1/Tanh_11_grad/TanhGrad_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/gradients_1/Tanh_10_grad/TanhGrad_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/gradients_1/Tanh_9_grad/TanhGrad_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_2/gradients_1/Tanh_8_grad/TanhGrad_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_9_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_9_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_9_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_9_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Tanh_8_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_10_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_10_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_10_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_10_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Tanh_9_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_11_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_11_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_11_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_11_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Tanh_10_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_12_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_12_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_12_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_12_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Tanh_11_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_13_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_13_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_13_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_13_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Tanh_12_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_14_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_14_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_14_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_14_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Tanh_13_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_15_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_15_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_15_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_15_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Tanh_14_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_16_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_16_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_16_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Add_16_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_3/gradients_1/Tanh_15_grad/TanhGrad_grad/mul/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# beta1_power/Initializer/initial_value: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# beta1_power: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# beta2_power/Initializer/initial_value: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# beta2_power: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable/Adam: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable/Adam_1: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_1/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_1/Adam: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_1/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_1/Adam_1: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_2/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_2/Adam: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_2/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_2/Adam_1: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_3/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_3/Adam: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_3/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_3/Adam_1: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_4/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_4/Adam: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_4/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_4/Adam_1: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_5/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_5/Adam: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_5/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_5/Adam_1: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_6/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_6/Adam: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_6/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_6/Adam_1: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_7/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_7/Adam: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_7/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_7/Adam_1: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_8/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_8/Adam: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_8/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_8/Adam_1: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_9/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_9/Adam: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_9/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_9/Adam_1: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_10/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_10/Adam: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_10/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_10/Adam_1: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_11/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_11/Adam: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_11/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_11/Adam_1: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_12/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_12/Adam: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_12/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_12/Adam_1: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_13/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_13/Adam: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_13/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_13/Adam_1: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_14/Adam/Initializer/zeros: (Const): /job:localhos
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 38
#      34 # print(X_u_train)
#      35 # print(X_u_train.shape)
#      36 # Create the model and train
#      37 model = PINN(X_u_train, u_train, layers, lb, ub)
# ---> 38 model.train(nIter=0)
#      40 # Predict and evaluate
#      41 u_pred, f_pred = model.predict(X_star)
#
# Cell In[5], line 166, in PINN.train(self, nIter)
#     163         print(f"It: {it}, Loss: {loss_value:.3e}, Lambda_1: {lambda_1_value:.3f}, Lambda_2: {lambda_2_value:.6f}, Time: {elapsed:.2f}")
#     164         start_time = time.time()
# --> 166 self.optimizer.minimize(self.sess, feed_dict=tf_dict, fetches=[self.loss, self.lambda_1, self.lambda_2], loss_callback=self.callback)
#
# TypeError: Optimizer.minimize() got an unexpected keyword argument 'feed_dict'
